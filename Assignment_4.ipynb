# %% [markdown]
# <a href="https://colab.research.google.com/github/YashicaV12/yashicaV/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Load the dataset into python environment
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-acada835-7984-4b52-bd5f-8510c49eea41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acada835-7984-4b52-bd5f-8510c49eea41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
 
path="/content/titanic_dataset (1).csv"
df=pd.read_csv(path)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#2. Make 'Passengerld' as the index column
import pandas as pd

data = pd.read_csv("titanic_dataset (1).csv")

data.set_index("PassengerId", inplace = True)
 
# display
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#3.Check the basic details of the dataset
df = pd.read_csv("titanic_dataset (1).csv") 
print("\nDataFrame information:")
print(df.info())
# Out:
# DataFrame information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
#4. Fill in all the missing values present in all the columns in the dataset
import pandas as pd 
     
data = pd.read_csv("titanic_dataset (1).csv") 
     
bool_series = pd.isnull(data["Age"]) 
 
# displaying data only with Age = NaN 
data[bool_series]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# importing pandas package 
import pandas as pd 
    
data = pd.read_csv("titanic_dataset (1).csv") 
     
bool_series = pd.isnull(data["Cabin"]) 

# displaying data only with Cabin = NaN 
data[bool_series]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# importing pandas package 
import pandas as pd 
     
data = pd.read_csv("titanic_dataset (1).csv") 
    
bool_series = pd.isnull(data["Embarked"]) 

# displaying data only with Embarked = NaN 
data[bool_series]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
#5.Check and handle outliers in at least 3 columns in the dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('titanic_dataset (1).csv')
df.head()
df.dtypes
missing_values=df.isnull().sum()
missing_values[missing_values>0]/len(df)*100
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
df.drop(['PassengerId','Name','Ticket'l,'Cabin'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df['Fare'].hist()
# Out:
# <Axes: >

# %%
print('skewness value of Age: ', df['Age'].skew())

print('skewness value of Fare: ',df['Fare'].skew())
# Out:
# skewness value of Age:  0.38910778230082704
# skewness value of Fare:  4.787316519674893

# %%
#Do min max scaling on the feature set (Take 'Survived' as target)
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

path="/content/titanic_dataset (1).csv"
df=pd.read_csv(path)

X- df.drop('Survived', axis=1)

y=df['Survived']

MinMaxScaler()

X_scaler.fit_transform(X)

df scaled = pd.DataFrame(X_scaled, columns-X)

df scaled['' Survived] = y

Display the modified DataFrame

print of scaled
# Out:
#   File "<ipython-input-31-14381238e666>", line 16
#     df scaled = pd.DataFrame(X_scaled, columns-X)
#        ^
# SyntaxError: invalid syntax
