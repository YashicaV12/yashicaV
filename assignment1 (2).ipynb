# %%
#READ THE DATSET
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e0ba80a-1b70-4b38-9f70-420a40be71bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e0ba80a-1b70-4b38-9f70-420a40be71bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#IMPORT PANDAS
import pandas as pd

# %%
#(1)READ THE CSV FILE
path="/content/iris (1).csv"
df=pd.read_csv(path)
df.head(151)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#(2)DISPLAYS THE COLUMNS IN THE DATASET
df.columns.values.tolist()
# Out:
# ['SL', 'SW', 'PL', 'PW', 'Classification']

# %%
#DISPLAYS THE DATASETS COLUMNS
pd.set_option('display.max_columns',151)
df.head(151)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#(3)CALCULATE THE MEAN OF EACH COULMN OF THE DATASET
#MEAN VALUE FOR "SL" COLUMN
df2=df["SL"].mean()
print(df2)
# Out:
# 5.843333333333334

# %%
#MEAN VALUE FOR "SW" COLUMN
df2=df["SW"].mean()
print(df2)
# Out:
# 3.0540000000000003

# %%
#MEAN VALUE FOR "PL" COLUMN
df2=df["PL"].mean()
print(df2)
# Out:
# 3.758666666666666

# %%
#MEAN VALUE FOR "PW" COLUMN
df2=df["PW"].mean()
print(df2)
# Out:
# 1.1986666666666668

# %%
#(4)CHECK THE 'NULL VALUES" PRESENT IN THE DATASETS
df.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#(5)PERFORM MEANINGFUL VISUALIZATIONS USING THE DATASET
#1.DATAFRAMES.PLOT()
df.plot()
# Out:
# <Axes: >

# %%
#2.DATAFRAMES.PLOT."HISTOGRAMS()""
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#3.DATAFRAMES.PLOT."BAR CHART"
df.plot(kind="bar")
# Out:
# <Axes: >
